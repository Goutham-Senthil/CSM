# %%
# Libraries
import os
import sys
import pandas as pd
import numpy as np
import scipy.io

# %%
# Dataset
df = pd.read_csv('Dataset\\Data2024.xlsx - Monthly.csv')

# %%
# this works
df
# Out:
#       yyyymm    price      d12       e12       ret      retx     AAA     BAA  \
# 0     187101     4.44   0.2600    0.4000       NaN       NaN     NaN     NaN
# 1     187102     4.50   0.2600    0.4000       NaN       NaN     NaN     NaN
# 2     187103     4.61   0.2600    0.4000       NaN       NaN     NaN     NaN
# 3     187104     4.74   0.2600    0.4000       NaN       NaN     NaN     NaN
# 4     187105     4.86   0.2600    0.4000       NaN       NaN     NaN     NaN
# ...      ...      ...      ...       ...       ...       ...     ...     ...
# 1843  202408  5648.40  72.9255  198.8233  0.024283  0.022898  0.0487  0.0560
# 1844  202409  5762.48  73.4003  200.2700  0.022821  0.021707  0.0468  0.0542
# 1845  202410  5705.45  73.8776  203.5700 -0.008690 -0.009523  0.0495  0.0563
# 1846  202411  6032.38  74.3549  206.8700  0.060420  0.059016  0.0514  0.0578
# 1847  202412  5881.63  74.8323  210.1700 -0.023445 -0.024621  0.0520  0.0580
#
# ...

# %%
# We are concered with 8 variables

# We are concered with the time period 

# January 1948 to December 2021

# %%
type(df['yyyymm'][0])
# Out:
# numpy.int64

# %%
df = df[df['yyyymm'] >= 194801]
df = df[df['yyyymm'] <= 202112]

# %%
df
# Out:
#       yyyymm    price      d12       e12       ret      retx     AAA     BAA  \
# 924   194801    14.69   0.8433    1.6433 -0.037743 -0.038905  0.0286  0.0352
# 925   194802    14.00   0.8467    1.6767 -0.040232 -0.047782  0.0285  0.0353
# 926   194803    15.08   0.8500    1.7100  0.081440  0.077022  0.0283  0.0353
# 927   194804    15.48   0.8500    1.7600  0.030821  0.028537  0.0278  0.0347
# 928   194805    16.69   0.8500    1.8100  0.084014  0.077523  0.0276  0.0338
# ...      ...      ...      ...       ...       ...       ...     ...     ...
# 1807  202108  4522.68  58.7913  169.8333  0.030600  0.029205  0.0255  0.0324
# 1808  202109  4307.54  59.2545  175.3700 -0.046077 -0.047152  0.0253  0.0323
# 1809  202110  4605.38  59.6354  182.8700  0.070510  0.069627  0.0268  0.0335
# 1810  202111  4567.00  60.0162  190.3700 -0.007256 -0.008666  0.0262  0.0328
# 1811  202112  4766.18  60.3971  197.8700  0.043485  0.042285  0.0265  0.0330
#
# ...

# %%
# Dividend-price ratio (d/p)
# Default yield spread (dfy)
# Term spread (tms)
# Treasury bill rate (tbl)
# Long-term government bond return (ltr)
# Default return spread (dfr)
# Net equity expansion (ntis)
# Inflation (infl)


prdictors = ['d/p', 'dfy', 'tms', 'tbl', 'ltr', 'dfr', 'ntis', 'infl']

# %%
# 57 columns
list(df.columns)
# Out:
# ['yyyymm',
#  'price',
#  'd12',
#  'e12',
#  'ret',
#  'retx',
#  'AAA',
#  'BAA',
#  'lty',
#  'ltr',
#  'corpr',
#  'tbl',
#  'Rfree',
#  'd/p',
#  'd/y',
#  'e/p',
#  'd/e',
#  'b/m',
#  'tms',
#  'dfy',
#  'dfr',
#  'infl',
#  'eqis',
#  'ntis',
#  'svar',
#  'cay',
#  'i/k',
#  'csp',
#  'pce',
#  'vp',
#  'impvar',
#  'vrp',
#  'govik',
#  'lzrt',
#  'skew',
#  'crdstd',
#  'ogap',
#  'wtexas',
#  'accrul',
#  'cfacc',
#  'sntm',
#  'ndrbl',
#  'skvw',
#  'tail',
#  'fbm',
#  'dtoy',
#  'dtoat',
#  'ygap',
#  'rdsp',
#  'rsvix',
#  'gpce',
#  'gip',
#  'tchi',
#  'house',
#  'avgcor',
#  'shtint',
#  'disag']

# %%
X = df[prdictors]
